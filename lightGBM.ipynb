# %%
from datetime import date, timedelta
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import lightgbm as lgb

# %%
# df_train = pd.read_csv('train.csv', dtype={'onpromotion': bool},
#                        converters={'unit_sales': lambda u: np.log1p(float(u)) if float(u) > 0 else 0},
#                        parse_dates=["date"], skiprows=range(1, 66458909))

# %%
#df_train = df_train_raw.loc[df_train_raw['date']>=pd.datetime(2016,1,1)]

# %%
# train on 2017 data
df_train = pd.read_csv('train.csv', dtype={'onpromotion': bool},
                       converters={'unit_sales': lambda u: np.log1p(float(u)) if float(u) > 0 else 0},
                       parse_dates=["date"], skiprows = range(1,101688780))

# %%
date_index = pd.date_range(df_train['date'].min(), df_train['date'].max())

# %%
df_test = pd.read_csv("test.csv", dtype={'onpromotion': bool}, parse_dates=["date"]).set_index(['store_nbr', 'item_nbr', 'date'])

# %%
items = pd.read_csv("items.csv").set_index("item_nbr")

# %%
# flatten promo across dates
promo_train = df_train.set_index(["store_nbr", "item_nbr", "date"])[["onpromotion"]].unstack(level=-1).fillna(False)
promo_train.columns = promo_train.columns.get_level_values(1)
promo_test = df_test[["onpromotion"]].unstack(level=-1).fillna(False)
promo_test.columns = promo_test.columns.get_level_values(1)

# %%
promo_train = promo_train.reindex(date_index.values, axis = 1).fillna(False)

# %%
promo_test = promo_test.reindex(promo_train.index).fillna(False) #align two ds, disregard missing test items 
promo = pd.concat([promo_train, promo_test], axis=1)
del promo_test, promo_train

# %%
df_train = df_train.set_index(["store_nbr", "item_nbr", "date"])["unit_sales"].unstack(level=-1).fillna(0)

# %%
df_train = df_train.reindex(date_index.values, axis = 1).fillna(0)

# %%
items = items.reindex(df_train.index.get_level_values(1)) #delete items not in train, align item index to train index

# %%
def get_timespan(df, dt, minus, periods, freq='D'): #slicing data by date, trace back "minus" days
    return df[pd.date_range(dt - timedelta(days=minus), periods=periods, freq=freq)]

# %%
def prepare_dataset(data, promo, t_anchor, is_train=True):
    X = pd.DataFrame({
        "day_1_2017": get_timespan(data, t_anchor, 1, 1).values.ravel(),
        "mean_3_2017": get_timespan(data, t_anchor, 3, 3).mean(axis=1).values,
        "mean_7_2017": get_timespan(data, t_anchor, 7, 7).mean(axis=1).values,
        "mean_14_2017": get_timespan(data, t_anchor, 14, 14).mean(axis=1).values,
        "mean_30_2017": get_timespan(data, t_anchor, 30, 30).mean(axis=1).values,
        "mean_60_2017": get_timespan(data, t_anchor, 60, 60).mean(axis=1).values,
        "mean_140_2017": get_timespan(data, t_anchor, 140, 140).mean(axis=1).values,
        "promo_14_2017": get_timespan(promo, t_anchor, 14, 14).sum(axis=1).values,
        "promo_60_2017": get_timespan(promo, t_anchor, 60, 60).sum(axis=1).values,
        "promo_140_2017": get_timespan(promo, t_anchor, 140, 140).sum(axis=1).values
#         "oil_14_2017": get_timespan(oil, t_anchor, 14, 14).mean(axis=1).values,
#         "oil_60_2017": get_timespan(oil, t_anchor, 60, 60).mean(axis=1).values,
#         "oil_140_2017": get_timespan(oil, t_anchor, 140, 140).mean(axis=1).values        
    })
    for i in range(7):
        X['mean_4_dow{}_2017'.format(i)] = get_timespan(data, t_anchor, 28-i, 4, freq='7D').mean(axis=1).values
        X['mean_20_dow{}_2017'.format(i)] = get_timespan(data, t_anchor, 140-i, 20, freq='7D').mean(axis=1).values
    for i in range(16):
        X["promo_{}".format(i)] = promo[t_anchor + timedelta(days=i)].values.astype(np.uint8)
#         X["oil_{}".format(i)] = oil[t_anchor + timedelta(days=i)].values
    if is_train:
        y = data[pd.date_range(t_anchor, periods=16)].values
        return X, y
    return X

# %%
#t2017 = date(2016, 6, 16)
t2017 = date(2017, 5, 31)
X_l, y_l = [], []
#for i in range(50):
for i in range(6):
    delta = timedelta(days=7 * i)
    X_tmp, y_tmp = prepare_dataset(df_train, promo, t2017 + delta)
    X_l.append(X_tmp)
    y_l.append(y_tmp)
X_train = pd.concat(X_l, axis=0)
y_train = np.concatenate(y_l, axis=0)
del X_l, y_l
X_val, y_val = prepare_dataset(df_train,promo, date(2017, 6, 16))
X_test = prepare_dataset(df_train, promo, date(2017, 8, 16), is_train=False)

# %%
params = {
    'num_leaves': 31,
    'objective': 'regression',
    'min_data_in_leaf': 300,
    'learning_rate': 0.1,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 2,
    'metric': 'l2_root',
    'num_threads': 12,
    'train_meric':True
}

MAX_ROUNDS = 500
val_pred = []
test_pred = []
cate_vars = []

# %%
for i in range(16):
    print("=" * 50)
    print("Step %d" % (i+1))
    print("=" * 50)
    dtrain = lgb.Dataset(X_train, label=y_train[:, i], categorical_feature=cate_vars,
#                         weight=pd.concat([items["perishable"]] * 50) * 0.25 + 1)
                         weight=pd.concat([items["perishable"]] * 6) * 0.25 + 1)
    dval = lgb.Dataset(X_val, label=y_val[:, i], reference=dtrain, weight=items["perishable"] * 0.25 + 1,
                       categorical_feature=cate_vars)
    bst = lgb.train(params, dtrain, num_boost_round=MAX_ROUNDS, valid_sets=[dtrain, dval],
                    early_stopping_rounds=50, verbose_eval=100)
    print("\n".join(("%s: %.2f" % x) for x in sorted(
        zip(X_train.columns, bst.feature_importance("gain")),
        key=lambda x: x[1], reverse=True
    )))
    val_pred.append(bst.predict(
        X_val, num_iteration=bst.best_iteration or MAX_ROUNDS))
    test_pred.append(bst.predict(
        X_test, num_iteration=bst.best_iteration or MAX_ROUNDS))
# Out:
# ==================================================
# Step 1
# ==================================================
# /home/tselab/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1027: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.549316	valid_1's rmse: 0.571352
# [200]	training's rmse: 0.546129	valid_1's rmse: 0.569432
# [300]	training's rmse: 0.543895	valid_1's rmse: 0.568983
# Early stopping, best iteration is:
# [320]	training's rmse: 0.543518	valid_1's rmse: 0.568938
# mean_7_2017: 1903546.14
# mean_14_2017: 1207198.66
# promo_0: 104078.13
# day_1_2017: 89370.55
# mean_20_dow0_2017: 86659.22
# mean_30_2017: 79924.94
# mean_3_2017: 71306.47
# mean_4_dow0_2017: 58256.87
# promo_14_2017: 28477.77
# mean_60_2017: 25679.34
# promo_7: 8518.08
# mean_140_2017: 7619.70
# promo_60_2017: 6142.98
# mean_4_dow5_2017: 5841.40
# promo_140_2017: 5243.72
# mean_20_dow4_2017: 4785.79
# mean_4_dow6_2017: 4260.24
# mean_20_dow2_2017: 3420.60
# mean_4_dow2_2017: 3141.94
# promo_9: 2849.14
# promo_14: 2308.76
# mean_20_dow3_2017: 2057.76
# mean_4_dow1_2017: 1955.94
# mean_20_dow1_2017: 1878.97
# mean_4_dow3_2017: 1773.88
# mean_20_dow6_2017: 1709.04
# mean_4_dow4_2017: 1708.13
# promo_15: 1385.90
# mean_20_dow5_2017: 1151.45
# promo_1: 1044.99
# promo_4: 1027.98
# promo_13: 1024.13
# promo_2: 884.37
# promo_11: 881.95
# promo_3: 760.39
# promo_12: 594.04
# promo_6: 301.17
# promo_10: 258.04
# promo_5: 209.31
# promo_8: 82.46
# ==================================================
# Step 2
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.571486	valid_1's rmse: 0.629719
# [200]	training's rmse: 0.568254	valid_1's rmse: 0.624866
# [300]	training's rmse: 0.566037	valid_1's rmse: 0.623895
# Early stopping, best iteration is:
# [309]	training's rmse: 0.565858	valid_1's rmse: 0.62365
# mean_14_2017: 1450342.86
# mean_7_2017: 995569.75
# mean_30_2017: 301697.68
# mean_20_dow1_2017: 74721.27
# promo_1: 63272.40
# mean_60_2017: 62904.39
# day_1_2017: 29392.39
# mean_3_2017: 24252.18
# promo_14_2017: 23141.80
# mean_4_dow1_2017: 15043.02
# mean_140_2017: 6590.48
# promo_60_2017: 4901.81
# mean_20_dow2_2017: 4836.86
# promo_0: 4409.69
# mean_20_dow4_2017: 4354.80
# promo_140_2017: 3463.94
# mean_4_dow2_2017: 3425.16
# promo_3: 3227.21
# mean_4_dow6_2017: 2776.94
# promo_4: 2583.93
# mean_4_dow0_2017: 2348.07
# mean_20_dow0_2017: 2251.05
# mean_4_dow4_2017: 2096.13
# mean_20_dow6_2017: 2025.69
# mean_4_dow3_2017: 1888.70
# mean_4_dow5_2017: 1752.99
# mean_20_dow5_2017: 1683.23
# mean_20_dow3_2017: 1360.45
# promo_5: 1347.04
# promo_2: 1332.68
# promo_7: 707.52
# promo_6: 536.36
# promo_14: 470.38
# promo_11: 357.09
# promo_13: 346.39
# promo_15: 328.03
# promo_9: 255.49
# promo_8: 157.01
# promo_10: 142.76
# promo_12: 87.03
# ==================================================
# Step 3
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.573753	valid_1's rmse: 0.594726
# [200]	training's rmse: 0.569965	valid_1's rmse: 0.59414
# Early stopping, best iteration is:
# [182]	training's rmse: 0.57053	valid_1's rmse: 0.594097
# mean_14_2017: 1856744.99
# mean_7_2017: 851234.43
# mean_30_2017: 237584.09
# mean_20_dow2_2017: 221604.35
# mean_4_dow2_2017: 211810.79
# promo_2: 97902.81
# mean_60_2017: 26147.73
# promo_14_2017: 24017.18
# mean_3_2017: 18010.52
# day_1_2017: 9855.23
# promo_60_2017: 9203.08
# promo_140_2017: 8232.68
# promo_3: 6769.97
# promo_9: 6029.54
# mean_20_dow4_2017: 5657.09
# promo_0: 4054.91
# promo_5: 3654.55
# mean_20_dow5_2017: 3508.08
# mean_4_dow1_2017: 3507.96
# promo_4: 3331.76
# mean_20_dow1_2017: 3060.86
# mean_4_dow0_2017: 2877.36
# promo_7: 2750.35
# mean_4_dow3_2017: 1871.09
# promo_11: 1847.26
# mean_140_2017: 1494.55
# mean_4_dow4_2017: 1439.42
# mean_20_dow3_2017: 1375.38
# mean_4_dow6_2017: 1287.01
# mean_20_dow0_2017: 1250.09
# mean_20_dow6_2017: 1164.36
# promo_14: 1151.98
# promo_15: 1045.11
# promo_1: 919.99
# mean_4_dow5_2017: 907.17
# promo_6: 767.28
# promo_13: 574.93
# promo_10: 546.55
# promo_12: 407.79
# promo_8: 199.34
# ==================================================
# Step 4
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.593678	valid_1's rmse: 0.597017
# [200]	training's rmse: 0.589792	valid_1's rmse: 0.596092
# Early stopping, best iteration is:
# [175]	training's rmse: 0.590613	valid_1's rmse: 0.59601
# mean_14_2017: 2142066.48
# mean_7_2017: 680456.25
# mean_30_2017: 552117.08
# mean_4_dow3_2017: 279318.33
# mean_20_dow3_2017: 154018.85
# mean_60_2017: 132462.06
# promo_3: 73494.35
# mean_3_2017: 48602.46
# mean_4_dow4_2017: 22200.91
# promo_14_2017: 17678.44
# promo_60_2017: 6861.29
# day_1_2017: 6151.63
# promo_5: 5323.80
# promo_140_2017: 5197.26
# mean_140_2017: 5061.30
# promo_4: 4931.30
# promo_7: 4503.13
# promo_2: 3995.55
# mean_20_dow4_2017: 3260.45
# mean_20_dow5_2017: 3240.55
# mean_20_dow0_2017: 2759.34
# mean_20_dow6_2017: 2670.40
# promo_0: 2589.74
# mean_4_dow2_2017: 2533.87
# promo_6: 2381.75
# promo_1: 1922.01
# mean_4_dow0_2017: 1896.73
# mean_20_dow2_2017: 1325.49
# promo_14: 1196.40
# mean_4_dow1_2017: 1065.81
# mean_4_dow6_2017: 1062.42
# mean_4_dow5_2017: 953.18
# mean_20_dow1_2017: 901.06
# promo_9: 755.34
# promo_8: 683.93
# promo_10: 539.57
# promo_13: 388.74
# promo_15: 326.68
# promo_11: 221.58
# promo_12: 140.16
# ==================================================
# Step 5
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.602514	valid_1's rmse: 0.594241
# [200]	training's rmse: 0.598225	valid_1's rmse: 0.592507
# [300]	training's rmse: 0.595243	valid_1's rmse: 0.591678
# Early stopping, best iteration is:
# [326]	training's rmse: 0.594605	valid_1's rmse: 0.591583
# mean_14_2017: 1482616.19
# mean_4_dow4_2017: 1173169.11
# mean_7_2017: 641778.68
# mean_30_2017: 401481.12
# mean_20_dow4_2017: 287054.92
# mean_3_2017: 255036.06
# promo_4: 73746.01
# mean_60_2017: 35704.10
# mean_4_dow3_2017: 18776.17
# promo_14_2017: 17858.73
# promo_60_2017: 8992.33
# promo_3: 7246.87
# promo_5: 7065.06
# promo_7: 7020.41
# promo_140_2017: 5840.68
# day_1_2017: 5235.96
# mean_20_dow1_2017: 4719.71
# mean_20_dow0_2017: 4320.97
# mean_20_dow2_2017: 3902.32
# promo_0: 3803.48
# promo_2: 3430.65
# promo_6: 3264.14
# mean_140_2017: 3013.35
# mean_20_dow3_2017: 2868.01
# promo_1: 2798.61
# mean_4_dow0_2017: 2546.83
# promo_11: 2343.21
# mean_4_dow6_2017: 2288.83
# mean_20_dow5_2017: 2183.66
# mean_20_dow6_2017: 2177.05
# mean_4_dow5_2017: 2071.73
# mean_4_dow2_2017: 1939.00
# promo_14: 1723.28
# mean_4_dow1_2017: 1668.35
# promo_9: 1310.14
# promo_13: 736.15
# promo_15: 728.69
# promo_12: 607.69
# promo_10: 577.03
# promo_8: 410.07
# ==================================================
# Step 6
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.596667	valid_1's rmse: 0.579253
# [200]	training's rmse: 0.593149	valid_1's rmse: 0.578473
# [300]	training's rmse: 0.590557	valid_1's rmse: 0.578056
# Early stopping, best iteration is:
# [291]	training's rmse: 0.590736	valid_1's rmse: 0.577986
# mean_14_2017: 1237087.13
# mean_30_2017: 1121383.33
# mean_7_2017: 378057.65
# mean_3_2017: 253833.79
# mean_60_2017: 180815.76
# mean_20_dow5_2017: 91261.09
# promo_5: 79935.30
# mean_4_dow5_2017: 61373.12
# promo_14_2017: 20435.76
# promo_3: 11533.08
# promo_7: 7876.23
# day_1_2017: 6827.32
# promo_60_2017: 6237.09
# promo_6: 5900.46
# mean_140_2017: 5713.99
# mean_20_dow6_2017: 5691.69
# mean_4_dow6_2017: 5382.48
# promo_140_2017: 4640.99
# mean_20_dow0_2017: 3690.15
# mean_20_dow3_2017: 3288.15
# mean_4_dow0_2017: 3188.54
# mean_20_dow2_2017: 3010.46
# mean_4_dow2_2017: 2638.20
# promo_4: 2507.96
# promo_2: 2369.19
# promo_9: 2160.35
# mean_4_dow4_2017: 2154.57
# promo_0: 2135.59
# mean_4_dow1_2017: 2126.80
# mean_20_dow4_2017: 1856.70
# mean_4_dow3_2017: 1820.52
# mean_20_dow1_2017: 1602.36
# promo_1: 1182.62
# promo_14: 1176.43
# promo_13: 963.57
# promo_12: 838.58
# promo_10: 709.91
# promo_8: 700.46
# promo_11: 681.04
# promo_15: 517.36
# ==================================================
# Step 7
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# Early stopping, best iteration is:
# [36]	training's rmse: 0.59629	valid_1's rmse: 0.588043
# mean_14_2017: 1098826.66
# mean_30_2017: 1018163.88
# mean_7_2017: 357873.22
# mean_20_dow6_2017: 176400.80
# mean_60_2017: 171886.23
# mean_4_dow6_2017: 128853.37
# mean_3_2017: 127662.53
# promo_6: 126523.14
# promo_14_2017: 17953.80
# day_1_2017: 10641.32
# promo_3: 10460.46
# promo_7: 7577.71
# mean_20_dow5_2017: 6907.03
# mean_4_dow5_2017: 5976.82
# promo_60_2017: 4242.92
# promo_5: 3387.21
# mean_140_2017: 2993.55
# promo_13: 2296.25
# promo_140_2017: 1828.75
# mean_20_dow1_2017: 1712.84
# promo_0: 1617.81
# promo_9: 1608.97
# mean_4_dow1_2017: 1224.84
# mean_20_dow0_2017: 1030.08
# promo_4: 960.16
# promo_14: 479.95
# mean_4_dow0_2017: 423.15
# promo_15: 407.62
# mean_20_dow3_2017: 394.72
# promo_2: 334.01
# mean_4_dow2_2017: 281.34
# promo_1: 269.15
# mean_20_dow4_2017: 198.77
# promo_10: 124.54
# promo_11: 119.93
# mean_20_dow2_2017: 81.60
# mean_4_dow3_2017: 53.53
# mean_4_dow4_2017: 0.00
# promo_8: 0.00
# promo_12: 0.00
# ==================================================
# Step 8
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.576755	valid_1's rmse: 0.592306
# [200]	training's rmse: 0.573131	valid_1's rmse: 0.591929
# Early stopping, best iteration is:
# [168]	training's rmse: 0.574022	valid_1's rmse: 0.591541
# mean_30_2017: 1109989.43
# mean_14_2017: 1071423.47
# mean_7_2017: 629795.22
# promo_7: 180545.74
# mean_20_dow0_2017: 150973.86
# mean_60_2017: 150601.54
# mean_4_dow0_2017: 79970.25
# promo_0: 22557.85
# mean_3_2017: 20700.54
# day_1_2017: 16245.19
# promo_14_2017: 13247.19
# promo_60_2017: 11974.65
# promo_14: 9229.45
# promo_140_2017: 7837.04
# promo_3: 5793.06
# mean_140_2017: 5438.36
# mean_20_dow2_2017: 4656.11
# mean_20_dow4_2017: 4629.65
# promo_5: 3654.87
# mean_20_dow1_2017: 2917.56
# promo_6: 2863.47
# mean_4_dow5_2017: 2046.51
# promo_9: 1904.09
# mean_20_dow3_2017: 1865.66
# mean_4_dow6_2017: 1848.67
# promo_4: 1778.66
# promo_2: 1725.99
# mean_4_dow2_2017: 1549.78
# mean_20_dow6_2017: 1449.08
# promo_15: 1440.22
# mean_4_dow3_2017: 1331.96
# mean_4_dow1_2017: 1308.45
# mean_20_dow5_2017: 1239.41
# mean_4_dow4_2017: 1154.68
# promo_10: 1106.89
# promo_8: 963.89
# promo_13: 729.59
# promo_11: 674.01
# promo_1: 400.33
# promo_12: 375.13
# ==================================================
# Step 9
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.584852	valid_1's rmse: 0.625836
# [200]	training's rmse: 0.581338	valid_1's rmse: 0.621554
# Early stopping, best iteration is:
# [214]	training's rmse: 0.580982	valid_1's rmse: 0.621366
# mean_30_2017: 1046600.87
# mean_14_2017: 763912.70
# mean_7_2017: 417305.47
# mean_60_2017: 320744.57
# mean_20_dow1_2017: 122462.74
# promo_8: 104384.40
# mean_4_dow1_2017: 20714.08
# promo_10: 17360.75
# promo_14_2017: 16905.54
# day_1_2017: 14728.62
# mean_3_2017: 11515.68
# promo_60_2017: 10456.63
# promo_7: 8064.64
# mean_20_dow2_2017: 7926.61
# promo_140_2017: 4850.59
# mean_20_dow4_2017: 4686.63
# promo_13: 3274.72
# promo_12: 3263.45
# promo_11: 3216.02
# mean_140_2017: 2999.83
# mean_4_dow0_2017: 2887.38
# mean_20_dow0_2017: 2641.38
# mean_4_dow6_2017: 2588.15
# promo_9: 2564.55
# mean_4_dow2_2017: 2143.29
# promo_0: 2064.00
# promo_3: 1979.51
# mean_20_dow6_2017: 1873.73
# mean_4_dow5_2017: 1580.94
# mean_20_dow5_2017: 1496.27
# promo_14: 1419.91
# mean_4_dow4_2017: 1407.65
# mean_4_dow3_2017: 1192.12
# promo_6: 1059.02
# mean_20_dow3_2017: 985.02
# promo_4: 783.75
# promo_2: 593.12
# promo_15: 562.26
# promo_5: 405.25
# promo_1: 275.49
# ==================================================
# Step 10
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.588304	valid_1's rmse: 0.626997
# [200]	training's rmse: 0.584358	valid_1's rmse: 0.625726
# [300]	training's rmse: 0.581585	valid_1's rmse: 0.625103
# Early stopping, best iteration is:
# [279]	training's rmse: 0.582091	valid_1's rmse: 0.625024
# mean_30_2017: 1024256.46
# mean_14_2017: 935014.66
# mean_7_2017: 441204.08
# mean_20_dow2_2017: 419866.35
# mean_4_dow2_2017: 311007.49
# promo_9: 128083.31
# mean_60_2017: 70912.44
# promo_14_2017: 21034.43
# promo_10: 14759.52
# promo_2: 12354.68
# promo_140_2017: 11879.25
# mean_3_2017: 10086.26
# promo_60_2017: 9908.83
# promo_7: 7133.16
# day_1_2017: 7114.28
# mean_20_dow4_2017: 6662.90
# promo_8: 5755.15
# mean_20_dow1_2017: 5657.92
# promo_14: 5516.02
# mean_4_dow1_2017: 5327.90
# mean_20_dow5_2017: 4171.63
# promo_12: 3833.94
# mean_4_dow0_2017: 3670.96
# mean_20_dow0_2017: 3513.26
# promo_11: 3407.86
# mean_4_dow3_2017: 2535.45
# mean_20_dow3_2017: 2267.82
# promo_13: 2239.26
# mean_4_dow4_2017: 2137.80
# mean_20_dow6_2017: 2052.66
# mean_140_2017: 1922.72
# mean_4_dow6_2017: 1768.07
# mean_4_dow5_2017: 1651.16
# promo_0: 1251.56
# promo_6: 1149.68
# promo_1: 1035.75
# promo_4: 900.48
# promo_15: 828.04
# promo_3: 418.25
# promo_5: 222.62
# ==================================================
# Step 11
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.611778	valid_1's rmse: 0.617785
# [200]	training's rmse: 0.607694	valid_1's rmse: 0.616785
# [300]	training's rmse: 0.604894	valid_1's rmse: 0.616784
# Early stopping, best iteration is:
# [253]	training's rmse: 0.606133	valid_1's rmse: 0.616699
# mean_30_2017: 1536463.51
# mean_14_2017: 780338.32
# mean_7_2017: 614031.80
# mean_60_2017: 390972.49
# mean_4_dow3_2017: 238398.80
# mean_20_dow3_2017: 182356.66
# promo_10: 105590.06
# mean_3_2017: 17339.67
# promo_14_2017: 15513.87
# mean_4_dow4_2017: 13707.82
# promo_60_2017: 10830.03
# mean_4_dow2_2017: 9054.91
# mean_140_2017: 8759.53
# promo_14: 7261.48
# promo_140_2017: 6920.59
# promo_7: 5541.64
# day_1_2017: 5058.35
# promo_12: 5044.06
# promo_11: 4989.59
# promo_9: 4873.60
# mean_20_dow5_2017: 4554.79
# promo_13: 4335.48
# mean_20_dow0_2017: 3998.85
# mean_20_dow2_2017: 3808.58
# promo_8: 3540.00
# mean_20_dow6_2017: 3473.36
# mean_20_dow4_2017: 3341.55
# mean_4_dow0_2017: 2762.65
# mean_20_dow1_2017: 2031.38
# promo_3: 1868.39
# mean_4_dow1_2017: 1796.67
# mean_4_dow6_2017: 1625.62
# mean_4_dow5_2017: 1585.13
# promo_0: 1298.73
# promo_6: 964.73
# promo_15: 882.52
# promo_4: 693.45
# promo_2: 544.36
# promo_5: 421.03
# promo_1: 334.07
# ==================================================
# Step 12
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.620279	valid_1's rmse: 0.610658
# [200]	training's rmse: 0.61551	valid_1's rmse: 0.607747
# [300]	training's rmse: 0.612429	valid_1's rmse: 0.606624
# [400]	training's rmse: 0.609935	valid_1's rmse: 0.605828
# [500]	training's rmse: 0.607768	valid_1's rmse: 0.605568
# mean_30_2017: 1426928.30
# mean_4_dow4_2017: 1198426.47
# mean_14_2017: 572079.48
# mean_20_dow4_2017: 286136.39
# mean_60_2017: 210657.23
# mean_7_2017: 206460.39
# mean_3_2017: 131502.42
# promo_11: 96123.91
# promo_14_2017: 16155.62
# promo_14: 13050.51
# promo_12: 12875.07
# mean_4_dow3_2017: 12837.60
# promo_140_2017: 9595.52
# promo_60_2017: 8636.61
# promo_10: 8398.42
# promo_13: 6495.04
# promo_9: 6103.76
# promo_4: 6003.23
# mean_20_dow0_2017: 5834.30
# mean_20_dow3_2017: 5747.96
# mean_140_2017: 5641.14
# day_1_2017: 5167.06
# mean_20_dow1_2017: 4786.19
# mean_20_dow6_2017: 4728.49
# promo_7: 4615.42
# mean_20_dow2_2017: 4054.25
# mean_4_dow0_2017: 3989.72
# mean_20_dow5_2017: 3787.13
# promo_8: 3520.46
# mean_4_dow5_2017: 3347.90
# mean_4_dow6_2017: 3256.90
# mean_4_dow2_2017: 3039.47
# mean_4_dow1_2017: 2883.12
# promo_0: 1840.79
# promo_15: 1648.87
# promo_6: 1614.35
# promo_2: 987.85
# promo_1: 711.74
# promo_3: 482.99
# promo_5: 416.87
# ==================================================
# Step 13
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.608497	valid_1's rmse: 0.592639
# [200]	training's rmse: 0.604691	valid_1's rmse: 0.591905
# [300]	training's rmse: 0.602037	valid_1's rmse: 0.591451
# Early stopping, best iteration is:
# [334]	training's rmse: 0.601316	valid_1's rmse: 0.591356
# mean_30_2017: 1524806.35
# mean_14_2017: 556090.01
# mean_7_2017: 367725.24
# mean_60_2017: 361402.68
# mean_3_2017: 188234.34
# promo_12: 94060.95
# mean_4_dow5_2017: 90723.27
# mean_20_dow5_2017: 88022.59
# promo_13: 18791.74
# promo_14_2017: 16387.91
# promo_14: 12822.54
# promo_10: 11620.23
# promo_60_2017: 8706.99
# day_1_2017: 7950.18
# mean_140_2017: 7540.77
# mean_20_dow0_2017: 6938.43
# promo_140_2017: 5765.42
# mean_20_dow6_2017: 5683.22
# promo_11: 5007.00
# mean_4_dow6_2017: 4478.37
# mean_20_dow3_2017: 3875.35
# mean_4_dow0_2017: 3726.99
# promo_9: 3511.84
# mean_20_dow2_2017: 3478.87
# mean_4_dow2_2017: 2713.79
# promo_15: 2585.61
# mean_4_dow4_2017: 2538.50
# mean_20_dow4_2017: 2518.83
# mean_20_dow1_2017: 2494.49
# mean_4_dow1_2017: 2347.70
# promo_7: 2335.76
# mean_4_dow3_2017: 2291.93
# promo_8: 1672.15
# promo_0: 1595.27
# promo_5: 1478.73
# promo_3: 1038.92
# promo_6: 1028.58
# promo_2: 697.44
# promo_4: 688.56
# promo_1: 353.53
# ==================================================
# Step 14
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.599507	valid_1's rmse: 0.596391
# Early stopping, best iteration is:
# [54]	training's rmse: 0.60342	valid_1's rmse: 0.595515
# mean_30_2017: 1478883.37
# mean_14_2017: 428879.30
# mean_7_2017: 341311.31
# mean_60_2017: 312677.40
# mean_20_dow6_2017: 221129.57
# promo_13: 160381.49
# mean_3_2017: 78993.50
# mean_4_dow6_2017: 66831.16
# day_1_2017: 19603.02
# promo_14_2017: 14035.65
# mean_4_dow5_2017: 10193.06
# mean_20_dow5_2017: 8425.12
# promo_14: 8387.65
# promo_10: 7871.18
# promo_60_2017: 7665.39
# mean_20_dow1_2017: 6492.33
# mean_140_2017: 6465.68
# promo_6: 4725.81
# promo_12: 4285.18
# promo_140_2017: 3824.62
# mean_20_dow0_2017: 3439.23
# promo_9: 2780.18
# promo_0: 2263.54
# promo_11: 2251.27
# mean_4_dow1_2017: 1886.86
# promo_15: 1811.33
# promo_8: 1031.95
# mean_20_dow3_2017: 872.76
# mean_4_dow0_2017: 768.09
# promo_7: 715.38
# promo_4: 555.39
# mean_20_dow4_2017: 542.57
# promo_3: 508.89
# promo_2: 455.23
# mean_4_dow4_2017: 371.25
# mean_4_dow2_2017: 308.58
# mean_20_dow2_2017: 300.58
# mean_4_dow3_2017: 253.23
# promo_1: 226.17
# promo_5: 22.50
# ==================================================
# Step 15
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.588958	valid_1's rmse: 0.60106
# [200]	training's rmse: 0.585267	valid_1's rmse: 0.600251
# [300]	training's rmse: 0.582426	valid_1's rmse: 0.600241
# Early stopping, best iteration is:
# [278]	training's rmse: 0.582937	valid_1's rmse: 0.600141
# mean_30_2017: 1547763.74
# mean_14_2017: 589243.44
# mean_7_2017: 405147.83
# mean_20_dow0_2017: 291282.75
# promo_14: 195973.82
# mean_60_2017: 171542.12
# mean_4_dow0_2017: 69227.48
# promo_7: 18019.69
# promo_14_2017: 16765.04
# day_1_2017: 15568.24
# mean_3_2017: 12462.40
# promo_0: 12404.69
# promo_140_2017: 11337.14
# promo_60_2017: 10862.15
# mean_20_dow2_2017: 9055.40
# promo_13: 8862.57
# mean_140_2017: 7233.21
# promo_12: 6307.16
# mean_20_dow4_2017: 5291.20
# mean_20_dow1_2017: 4524.15
# promo_10: 4314.65
# promo_9: 4022.94
# promo_15: 3970.95
# mean_4_dow6_2017: 2929.14
# mean_4_dow2_2017: 2692.33
# mean_20_dow6_2017: 2595.21
# mean_4_dow1_2017: 2445.81
# mean_4_dow5_2017: 2348.90
# mean_20_dow3_2017: 2178.70
# promo_11: 2010.60
# promo_2: 2000.09
# mean_4_dow4_2017: 1915.37
# mean_20_dow5_2017: 1896.49
# mean_4_dow3_2017: 1751.84
# promo_6: 1586.84
# promo_4: 1095.16
# promo_8: 846.16
# promo_5: 528.18
# promo_1: 483.96
# promo_3: 376.14
# ==================================================
# Step 16
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [100]	training's rmse: 0.597852	valid_1's rmse: 0.706405
# [200]	training's rmse: 0.594287	valid_1's rmse: 0.701382
# [300]	training's rmse: 0.591696	valid_1's rmse: 0.70052
# Early stopping, best iteration is:
# [330]	training's rmse: 0.591094	valid_1's rmse: 0.69984
# mean_30_2017: 1436311.50
# mean_60_2017: 436044.18
# mean_14_2017: 425793.78
# mean_7_2017: 203463.68
# promo_15: 133593.68
# mean_20_dow1_2017: 120980.69
# mean_20_dow2_2017: 17440.58
# day_1_2017: 14817.47
# mean_4_dow1_2017: 14426.26
# promo_60_2017: 11892.73
# promo_14_2017: 11787.38
# mean_3_2017: 8978.09
# promo_14: 8688.99
# promo_140_2017: 7397.87
# mean_140_2017: 6233.03
# mean_20_dow4_2017: 5713.40
# mean_20_dow0_2017: 4449.53
# mean_4_dow6_2017: 3536.06
# promo_10: 3441.43
# mean_4_dow2_2017: 2984.51
# mean_20_dow6_2017: 2828.38
# mean_4_dow0_2017: 2727.01
# promo_13: 2492.75
# mean_4_dow4_2017: 2443.99
# mean_4_dow3_2017: 2281.88
# mean_20_dow5_2017: 2215.51
# promo_12: 2175.91
# mean_4_dow5_2017: 2001.55
# mean_20_dow3_2017: 1777.64
# promo_0: 1691.21
# promo_9: 1604.27
# promo_7: 1527.54
# promo_11: 954.17
# promo_8: 921.36
# promo_6: 765.30
# promo_4: 748.13
# promo_2: 701.11
# promo_1: 618.85
# promo_3: 544.66
# promo_5: 413.55

# %%
print("Validation mse:", mean_squared_error(
    y_val, np.array(val_pred).transpose()))
# Out:
# Validation mse: 0.366799456115

# %%
print("Making submission...")
y_test = np.array(test_pred).transpose()
df_preds = pd.DataFrame(y_test, index=df_train.index, columns=pd.date_range("2017-08-16", periods=16)
                       ).stack().to_frame("unit_sales")
df_preds.index.set_names(["store_nbr", "item_nbr", "date"], inplace=True)
# Out:
# Making submission...

# %%
submission = df_test[["id"]].join(df_preds, how="left")#.fillna(0)
submission["unit_sales"] = np.clip(np.expm1(submission["unit_sales"]), 0, 1000)
submission.to_csv('default_nofill.csv', float_format='%.4f', index=None)

# %%
# predict unknown items by class average

# %%
# add class
df_preds2 = df_preds.unstack(-1)
item_idx = df_preds2.index.get_level_values(1)
df_preds2['class'] = items.reindex(item_idx)['class'].values
df_preds2['family'] = items.reindex(item_idx)['family'].values

# %%
class_pred = df_preds2.reset_index().drop(['item_nbr','family'], axis = 1).groupby(['store_nbr', 'class']).agg('mean')
class_pred = class_pred.stack()
# Out:
# /home/tselab/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:2530: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
# add family
family_pred = df_preds2.reset_index().drop(['item_nbr','class'], axis = 1).groupby(['store_nbr', 'family']).agg('mean')
family_pred = family_pred.stack()
# Out:
# /home/tselab/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:2530: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
submission = df_test[["id"]].join(df_preds, how="left")

# %%
item_idx = submission.index.get_level_values(1)

# %%
items = pd.read_csv("items.csv").set_index("item_nbr")

# %%
submission['class'] = items.reindex(item_idx)['class'].values
submission['family'] = items.reindex(item_idx)['family'].values

# %%
class_pred.rename(columns = {'unit_sales': 'class_sales'}, inplace = True)
submission = submission.reset_index().set_index(['store_nbr','class','date']).merge(class_pred, left_index = True,
                                                                      right_index = True, how = 'left')
submission['unit_sales'].fillna(submission['class_sales'], inplace = True)
submission.drop('class_sales', axis = 1, inplace = True)

# %%
family_pred.rename(columns = {'unit_sales': 'family_sales'}, inplace = True)
submission = submission.reset_index().set_index(['store_nbr','family','date']).merge(family_pred, left_index = True,
                                                                      right_index = True, how = 'left')
submission['unit_sales'].fillna(submission['family_sales'], inplace = True)
submission.drop('family_sales', axis = 1, inplace = True)

# %%
submission = submission.reset_index().drop(['family','class','store_nbr','item_nbr','date'], axis = 1).set_index(['id']).sort_index().fillna(0)

# %%
submission["unit_sales"] = np.clip(np.expm1(submission["unit_sales"]), 0, 1000)
submission.to_csv('default+meanclass.csv', float_format='%.4f')
